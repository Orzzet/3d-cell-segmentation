# %%
from preprocessing import generate_preprocessed_files

ORIGINAL_DATASET_PATH = 'data/cells/raw/'
NEW_DATASET_PATH = 'data/cells/lq_nobatch2/'
dim_reduction = (0.5,0.5,0.5)
filenames = list(filter(lambda name: name[0] != 'p', list(os.walk(ORIGINAL_DATASET_PATH))[0][2]))
compression_level = 4

generate_preprocessed_files(filenames, compression_level, dims_reduction=dim_reduction, batch=False, original_dataset_path=ORIGINAL_DATASET_PATH, new_dataset_path=NEW_DATASET_PATH)
# Out:
# Dimensiones image: (116, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2017-12-04_1a.mat 117s
# Dimensiones target: (116, 512, 512)
# Células original: [72]. Células ahora: 72
# Target c4(0.5, 0.5, 0.5)-Wildtype_2017-12-04_1a.mat 55s
#
# Dimensiones image: (132, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2017-12-04_3a.mat 89s
# Dimensiones target: (132, 514, 512)
# Células original: [83]. Células ahora: 84
# Target c4(0.5, 0.5, 0.5)-Wildtype_2017-12-04_3a.mat 53s
#
# Dimensiones image: (122, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2017-12-04_4a.mat 66s
# Dimensiones target: (122, 512, 512)
# Células original: [74]. Células ahora: 74
# Target c4(0.5, 0.5, 0.5)-Wildtype_2017-12-04_4a.mat 60s
#
# Dimensiones image: (126, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-04-10_1a.mat 87s
# Dimensiones target: (126, 514, 512)
# Células original: [67]. Células ahora: 67
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-04-10_1a.mat 51s
#
# Dimensiones image: (108, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-04-10_2a.mat 57s
# Dimensiones target: (108, 512, 512)
# Células original: [71]. Células ahora: 72
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-04-10_2a.mat 54s
#
# Dimensiones image: (148, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-11-30_OR 1 1a.mat 83s
# Dimensiones target: (148, 512, 512)
# Células original: [56]. Células ahora: 58
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-11-30_OR 1 1a.mat 74s
#
# Dimensiones image: (158, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-11-30_OR 1 6a.mat 97s
# Dimensiones target: (158, 512, 512)
# Células original: [77]. Células ahora: 77
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-11-30_OR 1 6a.mat 80s
#
# Dimensiones image: (184, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_1a.mat 119s
# Dimensiones target: (184, 512, 512)
# Células original: [54]. Células ahora: 55
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_1a.mat 90s
#
# Dimensiones image: (150, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_3a.mat 88s
# Dimensiones target: (150, 512, 512)
# Células original: [66]. Células ahora: 67
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_3a.mat 81s
#
# Dimensiones image: (162, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_4a.mat 99s
# Dimensiones target: (162, 512, 512)
# Células original: [47]. Células ahora: 48
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_4a.mat 76s
#
# Dimensiones image: (162, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_5a.mat 107s
# Dimensiones target: (162, 512, 512)
# Células original: [50]. Células ahora: 50
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_5a.mat 78s
#
# Dimensiones image: (152, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_7a.mat 102s
# Dimensiones target: (152, 514, 512)
# Células original: [68]. Células ahora: 69
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_7a.mat 58s
#
# Dimensiones image: (152, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_8a.mat 106s
# Dimensiones target: (152, 514, 512)
# Células original: [65]. Células ahora: 68
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-12-12_8a.mat 61s
#
# Dimensiones image: (178, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2018-12-26_3a.mat 189s
# Dimensiones target: (178, 514, 512)
# Células original: [73]. Células ahora: 73
# Target c4(0.5, 0.5, 0.5)-Wildtype_2018-12-26_3a.mat 82s
#
# Dimensiones image: (136, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2019-01-15_2a.mat 105s
# Dimensiones target: (136, 512, 512)
# Células original: [60]. Células ahora: 60
# Target c4(0.5, 0.5, 0.5)-Wildtype_2019-01-15_2a.mat 71s
#
# Dimensiones image: (142, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2019-01-15_3a.mat 94s
# Dimensiones target: (142, 512, 512)
# Células original: [86]. Células ahora: 86
# Target c4(0.5, 0.5, 0.5)-Wildtype_2019-01-15_3a.mat 70s
#
# Dimensiones image: (132, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2019-01-18_2a.mat 75s
# Dimensiones target: (132, 512, 512)
# Células original: [51]. Células ahora: 51
# Target c4(0.5, 0.5, 0.5)-Wildtype_2019-01-18_2a.mat 62s
#
# Dimensiones image: (158, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2019-01-18_4a.mat 107s
# Dimensiones target: (158, 512, 512)
# Células original: [51]. Células ahora: 52
# Target c4(0.5, 0.5, 0.5)-Wildtype_2019-01-18_4a.mat 74s
#
# Dimensiones image: (164, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2019-01-18_8a.mat 98s
# Dimensiones target: (164, 514, 512)
# Células original: [54]. Células ahora: 56
# Target c4(0.5, 0.5, 0.5)-Wildtype_2019-01-18_8a.mat 62s
#
# Dimensiones image: (172, 512, 512)
# Image c4(0.5, 0.5, 0.5)-Wildtype_2019-01-25_1a.mat 114s
# Dimensiones target: (172, 512, 512)
# Células original: [60]. Células ahora: 61
# Target c4(0.5, 0.5, 0.5)-Wildtype_2019-01-25_1a.mat 82s
